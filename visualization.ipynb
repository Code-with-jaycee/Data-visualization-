# %% [markdown]
# # MATPLOTLIB Tutorial

# %% [markdown]
# All imports

# %%
from matplotlib import pylab
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Fifa_world_cup.csv")
data.head(2)
# Out:
#      team1    team2 possession team1 possession team2 possession in contest  \
# 0    QATAR  ECUADOR              42%              50%                    8%
# 1  ENGLAND     IRAN              72%              19%                    9%
#
#    number of goals team1  number of goals team2         date     hour  \
# 0                      0                      2  20 NOV 2022  17 : 00
# 1                      6                      2  21 NOV 2022  14 : 00
#
#   category  ...  penalties scored team1  penalties scored team2  \
# 0  Group A  ...                       0                       1
# 1  Group B  ...                       0                       1
#
#    goal preventions team1  goal preventions team2  own goals team1  \
# 0                       6                       5                0
# 1                       8                      13                0
#
#    own goals team2  forced turnovers team1  forced turnovers team2  \
# ...

# %%
data.corr()
# Out:
#                                    number of goals team1  \
# number of goals team1                           1.000000
# number of goals team2                           0.018927
# total attempts team1                            0.400841
# total attempts team2                           -0.198041
# conceded team1                                  0.018927
# ...                                                  ...
# own goals team2                                -0.047324
# forced turnovers team1                         -0.014106
# forced turnovers team2                          0.027506
# defensive pressures applied team1              -0.081799
# defensive pressures applied team2               0.348401
#
#                                    number of goals team2  \
# number of goals team1                           0.018927
# number of goals team2                           1.000000
# total attempts team1                            0.102839
# ...

# %%
x = data["total attempts team1"]
y = data["goal preventions team2"]

m = data["conceded team1"]
n = data["goal inside the penalty area team2"]

pylab.plot(x, y,'r') # 'r' stands for red

# %% [markdown]
# <h4>Drawing a subgraph</h4>
# The contents of the brackets represent (rows, columns, indexes)

# %%
pylab.subplot(1, 2, 1) 
pylab.plot(x, y,color='red', lw=0.25 ,marker="o", markerfacecolor='red' )

pylab.subplot(2, 2, 2)
pylab.plot(m, n, color='green', lw=0.25 ,marker="o", markerfacecolor='green')

# %% [markdown]
# # Operator Description

# %% [markdown]
# fig.add_axes() = initilializes subplot a = fig.add_subplot(222)<br>
# fig, b = plt.subplots(nrows=3, nclos=2) = Adds subplot<br>
# ax = plt.subplots(2, 2) = Creates subplot

# %%
fig = plt.figure(dpi=400)
axis = fig.add_axes([0.5, 0.1, 1, 1]) # Control the left, right, width, height of the canvas (from 0 to 1)
axis.plot(x, y, 'r')

# %% [markdown]
# Subgraphs

# %%
fig, axes = plt.subplots(nrows=1, ncols= 2, dpi=400)  # Submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x, y, 'r')

# %% [markdown]
# x = data["total attempts team1"]<br>
# y = data["goal preventions team2"]<br>
#
# m = data["conceded team1"]<br>
# n = data["goal inside the penalty area team2"]

# %% [markdown]
# Draring a picture , or graph, inside another graph

# %%
fig = plt.figure(dpi=300)
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left , right, width, height
axes2 = fig.add_axes([0.2, 0.5, 0.2, 0.3])

axes1.plot(x, y,color='red', lw=0.25 ,marker="o", markerfacecolor='red')
axes1.set_xlabel("total attempts team1")
axes1.set_ylabel("goal preventions team2")
axes1.set_title("Fifa world cup 2022")
axes2.plot(m, n, color='green', lw=0.25 ,marker="o", markerfacecolor='green')
axes2.set_title("Penalty area goals")
# Out:
# Text(0.5, 1.0, 'Penalty area goals')

# %% [markdown]
# # fig = plt.figure(figsize=(16, 9), dpi=300)

# %%
fig = plt.figure(figsize=(16, 9), dpi=300)
fig.add_subplot()
plt.plot(x, y , 'r', marker="o")

# %%
fig, axes = plt.subplots(dpi=400)
axes.set_title("Fifa world cup")
axes.plot(x, y, color="red", marker="o")

# %% [markdown]
# # Adding title and labels

# %%
ax.legend(["Label1", "label2"])
fig, axes = plt.subplots(dpi= 200)
axes.set_xlabel('total attempts team1')
axes.set_ylabel('goal preventions team2')
axes.set_title("Fifa World Cup") # Adding title

axes.plot(x,y, 'r')
axes.plot(m,n, 'g-o')
axes.legend(["Attemps vs preventions", "Goal conceed vs Penalty area"], loc=2)

# %% [markdown]
# in matplotlib, you can set other properties such as Line color, transparency and more

# %%
fig, axes = plt.subplots(dpi= 400)
axes.plot(x, y, color='red', alpha=.5)
axes.plot(m, n, color='green', alpha=.5)

# %% [markdown]
# # Line width

# %%
fig, axes = plt.subplots(dpi= 400)
axes.plot(x, y, color='red', lw=0.25, linestyle='-')
axes.plot(m, n, color='green', lw = 1, linestyle ='-.' )

line, =axes.plot(x, y, color="black", lw=1.5)
line.set_dashes([5, 10, 4, 10])

# %%
ig, axes = plt.subplots(dpi= 400)
axes.plot(x, y, color='red', lw=0.25, marker='o', markerfacecolor="red")
axes.plot(m, n, color='blue', lw = 1, marker = '+', markerfacecolor="red")

# %% [markdown]
# # set the canvas grid and axis range

# %%
k  = np.linspace(1, 50, 25)
n = np.linspace(1, 20, 25)

fig, axes = plt.subplots(1, 2, dpi=400)

axes[0].plot(k, k**2, k, k**3, lw=2)
axes[0].grid(True)

axes[1].plot(k, k**2, k, k**3, lw=2)
axes[1].grid(True)
axes[1].set_ylim([0, 40000])
axes[1].set_xlim([10, 30])
# Out:
# (10.0, 30.0)

# %% [markdown]
# Other 2D Graphics

# %%
fig , axes = plt.subplots(1, 4, figsize=(16, 5), dpi=600)
axes[0].set_title("scatter")
axes[0].scatter(k, k**2, color='red')
axes[1].set_title("step plot")
axes[1].step(k, k**3)

axes[2].set_title("bar plot")
axes[2].bar(k, k**4, width=0.8)

axes[3].set_title("fill_between")
axes[3].fill_between(k, k**4, color='green', alpha=0.5)

# %% [markdown]
# # Drawing a radar chart

# %%
fig = plt.figure(figsize=(6, 6), dpi=400)
axes = fig.add_axes([0.0, 0.0, 1, 1], polar=True)

axes.plot(x, x, color='blue', lw=3)

# %% [markdown]
# # Histogram

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4), dpi=400)
axes[0].set_title("Default histogram")
axes[0].hist(m)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(m, cumulative=True, bins=50)
# Out:
# (array([23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 23., 42.,
#         42., 42., 42., 42., 42., 42., 42., 42., 42., 42., 42., 42., 57.,
#         57., 57., 57., 57., 57., 57., 57., 57., 57., 57., 57., 63., 63.,
#         63., 63., 63., 63., 63., 63., 63., 63., 63., 63., 64.]),
#  array([0.  , 0.08, 0.16, 0.24, 0.32, 0.4 , 0.48, 0.56, 0.64, 0.72, 0.8 ,
#         0.88, 0.96, 1.04, 1.12, 1.2 , 1.28, 1.36, 1.44, 1.52, 1.6 , 1.68,
#         1.76, 1.84, 1.92, 2.  , 2.08, 2.16, 2.24, 2.32, 2.4 , 2.48, 2.56,
#         2.64, 2.72, 2.8 , 2.88, 2.96, 3.04, 3.12, 3.2 , 3.28, 3.36, 3.44,
#         3.52, 3.6 , 3.68, 3.76, 3.84, 3.92, 4.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# # Drawing countour image
# meshgrid (MATLAB Functions) [X,Y] = meshgrid(x,y) transforms the domain specified by vectors x and y into arrays X and Y , which can be used to evaluate functions of two variables and three-dimensional mesh/surface plots.

# %%
delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)

X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2 - (Y - 1)** 2)
Z = (Z1 - Z2)* 2

# %%
fig, ax = plt.subplots(dpi=400)
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize= 10)
ax.set_title("Countour map")
# Out:
# Text(0.5, 1.0, 'Countour map')
